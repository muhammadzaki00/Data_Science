# %%
import pandas as pd
import numpy as np

# %%
 # buat array
data = np.array([
    [1,4],
    [2,5],
    [3,6]
])
data
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
df = pd.DataFrame(
    data,
    index=['baris1','baris2','baris3'],
    columns=['kolom1','kolom2']
)
df
# Out:
#         kolom1  kolom2
# baris1       1       4
# baris2       2       5
# baris3       3       6

# %%
# contoh membuat DataFrame sendiri
# pembuatan data /  data harus seimbang : 
provinsi = ['Kalimantan Selatan','Jawa Barat','Nusa Tenggara Timur']
jumlah_penduduk = [39613493, 29730311, 21944577]

# dictionary / dict
dict = {'Provinsi' : provinsi,
        'jumlah_penduduk' : jumlah_penduduk
}
# konversi ke DataFrame
df_jumlah_penduduk = pd.DataFrame(dict)
df_jumlah_penduduk
# Out:
#               Provinsi  jumlah_penduduk
# 0   Kalimantan Selatan         39613493
# 1           Jawa Barat         29730311
# 2  Nusa Tenggara Timur         21944577

# %%
df_ujian = pd.read_csv('StudentsPerformance.csv')
# menampilkan 1000 baris 8 kolom
df_ujian.shape
# Out:
# (1000, 8)

# %%
#pd.set_option('display.max_rows', 1000)
#df_ujian

# %%
df_ujian.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df_ujian.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df_ujian.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
# Menampilkan data sebanyak 5 baris :
df_ujian.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# menampilkan info tipe data
df_ujian.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# menjelaskan statistik dari data
df_ujian.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
len(df_ujian) # panjang data
max(df_ujian.index) # maksimal data
min(df_ujian.index) # minimal data
type (df_ujian) # menyajikan tipe data
round(df_ujian, 2) # ini untuk membulatkan
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df_ujian['writing score'] # memilih kolom
type(df_ujian['writing score']) # mengetahui tipe data
# df_ujian # menampikan semua kolom 
df_ujian[['gender','writing score']]  # MENAMPILKAN SEBAGIAN KOLOM
# Out:
#      gender  writing score
# 0    female             74
# 1    female             88
# 2    female             93
# 3      male             44
# 4      male             75
# ..      ...            ...
# 995  female             95
# 996    male             55
# 997  female             65
# 998  female             77
# 999  female             86
#
# [1000 rows x 2 columns]

# %%
df_ujian['language score'] = 70
df_ujian
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# membuat angka 0-1000
language_score = np.arange(0, 1000) # mulai dan jumlah
df_ujian['language score'] = language_score
df_ujian
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# membuat nilai acak dari 60 - 100, sebanyak 1000
int_language_score = np.random.randint(60,100, size=1000)
df_ujian['language score'] = int_language_score
df_ujian
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# membuat nilai acak dari 1 - 100 secara acak
np.random.uniform(1,100,size=1000)
# Out:
# array([20.72699216, 91.20597256, 32.37250561, 69.75200286,  2.04229067,
#        84.49513874, 35.67838569, 94.84880769,  9.32375147, 10.00727878,
#        72.16032068, 60.62455918,  9.02947957, 90.68667952,  9.48222546,
#         7.18972488,  6.43561227, 72.54320211, 14.1526265 , 88.36430484,
#        55.90507055, 19.87773483, 36.3464109 , 78.20024851, 20.49950658,
#        65.57576201, 21.93695896, 98.74049579, 12.82838605, 37.8563921 ,
#        92.177444  , 17.83238421, 16.04693232, 82.085358  , 43.61367521,
#        54.73954366, 32.34625312, 80.08881261, 41.00703278, 62.22837236,
#         9.14117734, 18.44541691, 12.47646956,  6.25468414, 65.79136299,
#        29.47141573,  5.89390726, 44.48297071, 92.75065919, 62.70360618,
#        33.70591916, 36.500526  , 22.3197544 , 35.9451827 , 82.68266958,
#        59.02835953, 80.23662856, 97.68046775, 20.13761087, 32.63923508,
#        91.40108258, 39.66438741, 67.41234859, 75.39396478, 56.149861  ,
# ...

# %%
score1 = np.random.uniform(1,100, size=1000)
score2 = np.random.uniform(1,100, size=1000)

score1
# Out:
# array([85.68791483, 26.8645178 , 89.380391  , 74.94410851, 11.04501406,
#        14.07914229, 42.99102959,  5.11290383, 98.33098672, 55.1825853 ,
#        64.82739542, 44.0300885 , 52.68831793, 60.30260181, 46.98884148,
#        35.08172828, 23.81808741, 22.32673529, 88.8352854 , 64.17561136,
#         2.34500911, 24.77633248, 59.24344249, 99.47188754, 86.08298409,
#        61.69962126, 61.88688931,  6.82531595, 69.63978306, 36.06258453,
#         1.42075455, 72.65129444, 85.85796185,  9.72450332, 95.82094541,
#        44.59269411, 27.31651386, 87.49950091, 70.22056976,  6.29100152,
#         3.65063158, 75.28717536, 99.98618448, 95.18017366, 38.88058009,
#         4.32870441, 45.3842698 , 23.53601598, 82.09208524, 52.60089111,
#        21.73800777, 26.53710801, 81.76518669, 18.15452148, 42.39969648,
#        16.11238579, 33.10682171, 12.42332386, 11.21931629, 22.04581453,
#        83.07616958, 35.51419051, 40.27335369, 73.45629173, 30.07328726,
# ...

# %%
series1 = pd.Series(score1, index = np.arange(0, 1000))
series2 = pd.Series(score2, index = np.arange(0, 1000))

series1

df_ujian = df_ujian.assign(score1 = series1, score2 = series2)
df_ujian
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#df_ujian.insert(1,'test 3', series1)
df_ujian
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
print (df_ujian['math score'].sum())
print (df_ujian['math score'].count())
print (df_ujian['math score'].mean())
print (df_ujian['math score'].std())
print (df_ujian['math score'].max())
print (df_ujian['math score'].min())
df_ujian.describe()
# Out:
# 66089
# 1000
# 66.089
# 15.16308009600945
# 100
# 0
#        math score  reading score  writing score  language score       score1  \
# count  1000.00000    1000.000000    1000.000000      1000.00000  1000.000000
# mean     66.08900      69.169000      68.054000        80.28500    48.825595
# std      15.16308      14.600192      15.195657        11.68479    28.291828
# min       0.00000      17.000000      10.000000        60.00000     1.420755
# 25%      57.00000      59.000000      57.750000        70.00000    23.622759
# 50%      66.00000      70.000000      69.000000        81.00000    47.401259
# 75%      77.00000      79.000000      79.000000        90.00000    73.136075
# max     100.00000     100.000000     100.000000        99.00000    99.986184
#
#             score2
# count  1000.000000
# mean     52.865398
# std      28.176487
# min       1.011685
# 25%      29.479681
# 50%      54.469512
# 75%      75.994176
# max      99.991934

# %%
df_ujian['rerata'] = (df_ujian['math score'] + df_ujian['reading score'] + df_ujian['writing score']) /3
df_ujian
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# untuk menghitung nilai
df_ujian['math score'].value_counts()
# Out:
# math score
# 65    36
# 62    35
# 69    32
# 59    32
# 73    27
#       ..
# 24     1
# 26     1
# 19     1
# 23     1
# 8      1
# Name: count, Length: 81, dtype: int64

# %%
# untuk menghitung nilai 
df_ujian['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
# untuk menghitung nilai dengan tanpilan ternormalisasi
df_ujian['race/ethnicity'].value_counts(normalize=True)
# Out:
# race/ethnicity
# group C    0.319
# group D    0.262
# group B    0.190
# group E    0.140
# group A    0.089
# Name: proportion, dtype: float64

# %%
# pembuatan 2 digit
df_ujian['race/ethnicity'].value_counts(normalize=True).round(2)
# Out:
# race/ethnicity
# group C    0.32
# group D    0.26
# group B    0.19
# group E    0.14
# group A    0.09
# Name: proportion, dtype: float64

# %%
# urut berdasarkan 1 kolom
df_ujian.sort_values('math score')
# urutan terbalik atau tidak
df_ujian.sort_values('math score', ascending=False)
# urutan berdasarkan 2 kolom atau ascending berarti
df_ujian.sort_values(['math score','reading score'],ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
import random
new_index = np.arange (0, 1000)
random.shuffle(new_index)# mengacak urutan
df_ujian ['new_index'] = new_index # untuk menambah kolom 
df_ujian.set_index('new_index', inplace=True) # untuk membuat new index sebagai index baru
df_ujian
df_ujian.sort_index()
df_ujian.sort_index(ascending=False)
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 999        female        group A                some college      standard
# 998          male        group D            some high school      standard
# 997        female        group D           bachelor's degree      standard
# 996          male        group D                 high school      standard
# 995          male        group B             master's degree  free/reduced
# ...           ...            ...                         ...           ...
# 4            male        group D           bachelor's degree      standard
# 3          female        group C           bachelor's degree  free/reduced
# 2          female        group C                 high school  free/reduced
# 1          female        group E          associate's degree  free/reduced
# 0          female        group C          associate's degree      standard
#
# ...

# %%
df_ujian.rename(columns={
    'math score' :'MS',
    'reading score' : 'RS',
    'writing score ': 'WS'                    }
, inplace=True)
df_ujian
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 411        female        group B           bachelor's degree      standard
# 917        female        group C                some college      standard
# 7          female        group B             master's degree      standard
# 417          male        group A          associate's degree  free/reduced
# 174          male        group C                some college      standard
# ...           ...            ...                         ...           ...
# 95         female        group E             master's degree      standard
# 169          male        group C                 high school  free/reduced
# 653        female        group C                 high school  free/reduced
# 516        female        group D                some college      standard
# 118        female        group D                some college  free/reduced
#
# ...
